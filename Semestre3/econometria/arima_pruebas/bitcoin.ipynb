# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima

# %%
# Cargamos el archivo CSV en un DataFrame de Pandas
file_path = 'BTC-USD.csv'
df = pd.read_csv(file_path)

# Mostramos las primeras filas del DataFrame para verificar la carga correcta de los datos
df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1822  2023-11-22  35756.554688  37856.980469  35670.972656  37432.339844
# 1823  2023-11-23  37420.433594  37643.917969  36923.863281  37289.621094
# 1824  2023-11-24  37296.316406  38415.339844  37261.605469  37720.281250
# 1825  2023-11-25  37721.414063  37892.429688  37617.417969  37796.792969
# 1826  2023-11-26  37796.828125  37820.300781  37177.011719  37487.601563
#
#          Adj Close       Volume
# 1822  37432.339844  24397247860
# 1823  37289.621094  14214948217
# 1824  37720.281250  22922957823
# 1825  37796.792969   9099571165
# 1826  37487.601563  13649179648

# %%
# Graficar la serie temporal de TIIE28
plt.figure(figsize=(14,7))
plt.plot(df.index, df['Close'], label='Close price', color='blue')
plt.title('Bitcoin Time Series')
plt.xlabel('Date')
plt.ylabel('Btc Value')
plt.legend()
plt.show()
