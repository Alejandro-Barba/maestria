# %% [markdown]
# # Exploratory analisys of the measureents for the iris flowers
# ## Alejandro Nathanael Martín del Campo Barba
#
# #### This data set contains 50 samples of each of three species of Iris:
# Iris setosa, Iris virginica and Iris versicolor, for each of these species four traits were
# measured for each sample: the length and width of the sepals and petals.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# fits i read the csv and save it to the df variable
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Describing the fields of the dataset
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Describing the Iris setosa
df[(df.Species == "Iris-setosa")].describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
# Describing the Iris versicolor
df[(df.Species == "Iris-versicolor")].describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
# Describing the Iris virginica
df[(df.Species == "Iris-virginica")].describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %% [markdown]
# ## Plot the iris dataset: Boxplot, Histogram Plot, Violin Plot, Scatter Plot, Andrews curve and proposed one multivariate graphical representation.

# %%
# I´m using the boxplot to check the distribution of the sepal lenght
sns.boxplot(x="Species", y="PetalLengthCm", data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
# I´m using the boxplot to check the distribution of the sepal Width
plt.hist(df['SepalWidthCm'])
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
# I´m using the violin plot to check the distribution of the sepal Width

sns.violinplot(x="Species", y="PetalLengthCm", data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# ## As we can see the petal length for the setosa is really diferent from the other 2 species, we can identify them very easily, for the Versicolor and the virginica some values are overlapping making them more dificult to identify

# %%
#Scatter plot to showthe distribution of the petal width
plt.scatter(df['PetalWidthCm'],df['Id'])

# %%
#Andrews curve
pd.plotting.andrews_curves(df.drop("Id", axis=1), "Species")
# Out:
# <AxesSubplot:>

# %%
#Multivariable graph representations
ax = df[['SepalLengthCm', 'SepalWidthCm','PetalLengthCm','PetalWidthCm']].plot(kind='box', title='boxplot')
df.drop("Id", axis=1).boxplot(by="Species")
plt.show()

# %% [markdown]
# # Conclusion
#
# ## With the visualizations obtained I can assume that the petal measurementes are a great way to identify the species of a given specimen with a high level of certainty because the measurements for each species have different values. The sepal measurements are not a great way to identify the soecies of the specimen because they are very similar in the 3 species

# %% [markdown]
# Exercises: Numerical examples
# 1.- Let X and Y be two random variables, denoting age and weight, respectively. Consider a
# random sample of size n= 20 from these two variables:
#
# X =(69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 76)
# Y =(153,175,155, 135, 172, 150, 115, 137,200,130,140,265,185,112, 140, 150, 165, 185,
# ,210,220)
#
# a. Find the mean, median, and mode for X.
# b. What is the variance for Y?
# c. Plot the normal distribution for X.
# d. What is the probability of observing an age of 80 or higher?
# e. Plot the normal distribution for Y.
#
# 2.- Respond “True or False” and provide a numerical example that provide support to the
# response:
# (a) Mean is robust against outliers.
# (b) Median is robust against outliers.
# (c) Standard deviation is robust against outliers.

# %%
X =(69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 76)
Y =(153,175,155, 135, 172, 150, 115, 137,200,130,140,265,185,112, 140, 150, 165, 185, 210, 220)

# %%
from statistics import mode

x_mean = np.mean(X)
x_median = np.median(X)
x_mode = mode(X)

print(f'A) the mean is {x_mean}')
print(f' the median is {x_median}')
print(f' the mode is {x_mode}')
# Out:
# A) the mean is 71.45
#  the median is 71.5
#  the mode is 74

# %%
y_var = np.var(Y)
print(f'The variance for weight is {y_var}')
# Out:
# The variance for weight is 1369.2099999999998

# %%
plt.hist(X)
# Out:
# (array([4., 2., 1., 3., 2., 0., 5., 2., 0., 1.]),
#  array([66. , 67.3, 68.6, 69.9, 71.2, 72.5, 73.8, 75.1, 76.4, 77.7, 79. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### d. What is the probability of observing an age of 80 or higher?
#
# ### In this exercise the probability is 0, because we dont have any age equal or higher than 80

# %%
#e. Plot the normal distribution for Y.
plt.hist(Y)
# Out:
# (array([2., 5., 4., 2., 3., 1., 1., 1., 0., 1.]),
#  array([112. , 127.3, 142.6, 157.9, 173.2, 188.5, 203.8, 219.1, 234.4,
#         249.7, 265. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 2.- Respond “True or False” and provide a numerical example that provide support to the response:
# - (a) Mean is robust against outliers.
# - (b) Median is robust against outliers.
# - (c) Standard deviation is robust against outliers.

# %%
# A is false, the mean is easily changed by altering only 1 single outlier

data = (69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 76)
data2 = (69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 500)

print(f'The original mean is {np.mean(data)}dd')
print(f'The modified mean is {np.mean(data2)}dd')
# Out:
# The original mean is 71.45dd
# The modified mean is 92.65dd

# %%
# B is true, the median is robust against outliers

data = (69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 76)
data2 = (69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 500)

print(f'The original median is {np.median(data)}dd')
print(f'The modified median is {np.median(data2)}dd')
# Out:
# The original median is 71.5dd
# The modified median is 71.5dd

# %%
# C is false, the strandar deviation is easily changed by altering only 1 single outlier

data = (69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 76)
data2 = (69,74,68, 70, 72, 67,66,70,76,68, 72, 79, 74,67,66,71,74, 75, 75, 500)

print(f'The original sdt is {np.std(data)}dd')
print(f'The modified sdtd is {np.std(data2)}dd')
# Out:
# The original sdt is 3.7212229172679243dd
# The modified sdtd is 93.52073299541658dd

# %% [markdown]
# ## References:
# https://www.kaggle.com/datasets/uciml/iris
#
# https://numpy.org/doc/stable/reference/generated/numpy.var.html
#
# https://matplotlib.org/stable/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
